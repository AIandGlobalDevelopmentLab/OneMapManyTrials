# %% [markdown]
# # Satellite Image Exporter (Landsat via GEE)
#
# This notebook downloads the satellite imagery used in the analysis from Google Earth Engine (GEE). For each DHS cluster, it retrieves a 6.72 × 6.72 km (224 × 224 px) image.
#
# - Image composition: For each pixel, the median value across cloud-free observations within the three years prior to the survey is used.
# - Sources: Imagery comes from Landsat 5, 7, and 8.
# - Runtime: Execution typically takes ~2 hours, although runtime may vary depending on GEE server load.
# - Output: The exported dataset is roughly 33 GB and is saved to the DATA_DIR specified in your config file.
#
# If the run is interrupted, simply rerun the notebook. Existing files are skipped, so already-downloaded tiles won’t be re-exported.

# %%
import ee
import os
import requests
import multiprocessing
import pandas as pd
import numpy as np
from io import BytesIO
from pathlib import Path
from retry import retry
from GEE.landsat_exporter import LandsatExporter
import configparser

# Read config file
config = configparser.ConfigParser()
config.read('../config.ini')

# # Authenticate with Google account (uncomment to authenticate)
# ee.Authenticate()

# Initialize Google Earth Engine with the High-volume endpoint
# For more info, see https://developers.google.com/earth-engine/cloud/highvolume
ee.Initialize(opt_url='https://earthengine-highvolume.googleapis.com')

# %%
DATA_DIR = config['PATHS']['DATA_DIR']
DOWNLOAD_DIR = os.path.join(DATA_DIR, 'dhs_images')
IMAGE_WIDTH = 6720
NUM_YEAR_SPAN = 3 # How many years before the survey should be used to get median image?
MASK_CLOUDS = True
DROP_FAULTY_L7 = True

df = pd.read_csv(os.path.join(DATA_DIR, 'dhs_data.csv'))
df.head()
# Out:
#         cluster_id        lon       lat  rural region_id country  \
# 0  AO.Bengo.71.135  13.640789 -8.589805  False  AO.Bengo  Angola
# 1  AO.Bengo.71.158  14.122619 -7.718385   True  AO.Bengo  Angola
# 2  AO.Bengo.71.169  13.654425 -8.592545  False  AO.Bengo  Angola
# 3  AO.Bengo.71.203  13.517859 -8.652260   True  AO.Bengo  Angola
# 4  AO.Bengo.71.208  13.721998 -7.852511   True  AO.Bengo  Angola
#
#                         survey  month  year        iwi
# 0  Angola 2015-16 Standard DHS     11  2015  62.334459
# 1  Angola 2015-16 Standard DHS      2  2016   8.226589
# 2  Angola 2015-16 Standard DHS     10  2015  62.760211
# 3  Angola 2015-16 Standard DHS      1  2016  68.211697
# 4  Angola 2015-16 Standard DHS     11  2015  14.825944

# %%
def get_file_name_generator(download_dir, num_year_span, mask_clouds, drop_faulty_l7):
    
    num_year_part = str(num_year_span) + '_year'
    mask_clouds_part = 'masked_clouds' if mask_clouds else 'with_clouds'
    drop_l7_part = 'without_slc_error' if drop_faulty_l7 else 'with_slc_error'

    # Define the file name based on the parameters. Use landsat.np for default settings
    if num_year_span == 3 and mask_clouds and drop_faulty_l7:
        file_name = 'landsat.np'
    else:
        file_name = f'landsat_{num_year_part}_median_{mask_clouds_part}_{drop_l7_part}.np'
    
    get_file_name = lambda id: os.path.join(download_dir, id, file_name)
    return get_file_name

# %% [markdown]
# Export images

# %%
get_file_name = get_file_name_generator(DOWNLOAD_DIR, NUM_YEAR_SPAN, MASK_CLOUDS, DROP_FAULTY_L7)

@retry(tries=10, delay=1, backoff=2)
def export_row_loc(row):
    
    id = row['cluster_id']
    file_name = get_file_name(id)
    
    # Check if sample already downloaded
    if os.path.exists(file_name):
        return
    
    # Ensure download directory exists
    Path(os.path.join(DOWNLOAD_DIR, id)).mkdir(parents=True, exist_ok=True)
    
    loc = ee.Geometry.Point([row['lon'], row['lat']])
    
    # Define end_date (survey date) and start_date (three years before)
    year = int(row['year'])
    month = max(int(row['month']), 1) # Set surveys with month 0 to month 1

    end_date = f'{year:04d}-{month:02d}-01'

    start_year = year - NUM_YEAR_SPAN
    start_date = f'{start_year:04d}-{month:02d}-01'

    loc_collection = LandsatExporter.get_collection(loc, start_date, end_date)
    
    # Get the median pixel values
    dwnld_img = loc_collection.median()

    # Get a IMAGE_WIDTH x IMAGE_WIDTH meter frame around cluster coordinate
    loc_bbox = loc.buffer(IMAGE_WIDTH/2).bounds()
    
    try:
        # Try to get the download URL
        loc_download_url = dwnld_img.getDownloadURL({
            'name': id,
            'region': loc_bbox,
            'dimensions': [224, 224],
            'filePerBand': False,
            'format': 'NPY'
        })
    except ee.EEException as e:
        # Check if the error message is "Expression evaluates to an image with no bands"
        if "Expression evaluates to an image with no bands" in str(e):
            # Catch only the desired exception and print the error message
            print(f'Error for row {id}: {str(e)}')
            return
        else:
            # Let other exceptions pass through
            print(f'Error for row {id}: {str(e)}')
            raise e
    
    r = requests.get(loc_download_url) # send get request
    
    if r.status_code == 200:  # HTTP GET: 200 OK
        
        # Load bytes as numpy array (bands as np.void)
        img = np.load(BytesIO(r.content))
        
        # Convert to a standard 3D numpy array (width, height, channels)
        img = np.stack([img[field] for field in img.dtype.names], axis=-1)
        
        # Save retrieved image
        with open(file_name, 'wb') as out_file:
              np.save(out_file, img)
    # retry, get request failed
    else:
        print(f'{r.status_code}: {r.reason}')
        raise HTTPException(status_code=r.status_code, detail=r.reason)

# %% [markdown]
# Some places evaluates to "an image with no bands". This means that not a single cloud-free image was available in the three years leading up to the survey.

# %%
# Get samples as list, since multiprocessing doesn't work with dataframes
clusters = [row for _, row in df.iterrows()]

n_workers = 40
pool = multiprocessing.Pool(n_workers)
pool.map(export_row_loc, clusters)
pool.close()
pool.join()
# Out:
# Error for row CM.Adamaoua.22.122: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.123: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.124: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.125: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.126: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.127: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.128: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.13: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.14: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.15: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.16: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.17: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.18: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.19: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.2: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.20: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.21: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.22: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.23: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.24: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.26: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.27: Expression evaluates to an image with no bands.
# Error for row CF.Rs V.31.504: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.3: Expression evaluates to an image with no bands.
# Error for row CF.Rs V.31.505: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.4: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.5: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.6: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.7: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.8: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.9: Expression evaluates to an image with no bands.
# Error for row CF.Rs V.31.520: Expression evaluates to an image with no bands.
# Error for row CF.Rs V.31.522: Expression evaluates to an image with no bands.
# Error for row CF.Rs V.31.530: Expression evaluates to an image with no bands.
# Error for row CI.South West.35.78: Expression evaluates to an image with no bands.
# Error for row CI.South West.35.79: Expression evaluates to an image with no bands.
# Error for row CI.South West.35.80: Expression evaluates to an image with no bands.
# Error for row CI.South West.35.83: Expression evaluates to an image with no bands.
# Error for row CI.South.35.157: Expression evaluates to an image with no bands.
# Error for row CI.South.35.158: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.50103030: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.50151005: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.50203032: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.50251054: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.50305014: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.50502033: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.50551049: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.50604056: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.50605027: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.50703006: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.50802002: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.50805042: Expression evaluates to an image with no bands.
# Error for row CI.South.35.162: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.50901007: Expression evaluates to an image with no bands.
# Error for row CI.South.35.163: Expression evaluates to an image with no bands.
# Error for row CI.South.35.164: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.50951036: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.51002006: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.51004031: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.51051027: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.51151010: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.51252020: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.51253001: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.51254039: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.51259058: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.51262018: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.51263042: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.51264015: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.51302016: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.51303058: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.51351064: Expression evaluates to an image with no bands.
# Error for row BJ.Ouémé.31.51404038: Expression evaluates to an image with no bands.
# Error for row CI.South.35.39: Expression evaluates to an image with no bands.
# Error for row CI.South.35.61: Expression evaluates to an image with no bands.
# Error for row CI.South.35.62: Expression evaluates to an image with no bands.
# Error for row CI.South.35.64: Expression evaluates to an image with no bands.
# Error for row CI.South.35.65: Expression evaluates to an image with no bands.
# Error for row CI.South.35.66: Expression evaluates to an image with no bands.
# Error for row BF.South.21.106: Expression evaluates to an image with no bands.
# Error for row BF.South.21.107: Expression evaluates to an image with no bands.
# Error for row BF.South.21.108: Expression evaluates to an image with no bands.
# Error for row BF.South.21.109: Expression evaluates to an image with no bands.
# Error for row BF.South.21.123: Expression evaluates to an image with no bands.
# Error for row BF.South.21.125: Expression evaluates to an image with no bands.
# Error for row BF.South.21.174: Expression evaluates to an image with no bands.
# Error for row BF.South.21.178: Expression evaluates to an image with no bands.
# Error for row BF.South.21.180: Expression evaluates to an image with no bands.
# Error for row BF.South.21.185: Expression evaluates to an image with no bands.
# Error for row BF.South.21.186: Expression evaluates to an image with no bands.
# Error for row BF.South.21.187: Expression evaluates to an image with no bands.
# Error for row BF.South.21.188: Expression evaluates to an image with no bands.
# Error for row BF.South.21.190: Expression evaluates to an image with no bands.
# Error for row BF.South.21.191: Expression evaluates to an image with no bands.
# Error for row BF.South.21.193: Expression evaluates to an image with no bands.
# Error for row BF.South.21.198: Expression evaluates to an image with no bands.
# Error for row BF.South.21.199: Expression evaluates to an image with no bands.
# Error for row BF.South.21.200: Expression evaluates to an image with no bands.
# Error for row BF.South.21.201: Expression evaluates to an image with no bands.
# Error for row BF.South.21.202: Expression evaluates to an image with no bands.
# Error for row BF.South.21.54: Expression evaluates to an image with no bands.
# Error for row BF.South.21.55: Expression evaluates to an image with no bands.
# Error for row BF.South.21.56: Expression evaluates to an image with no bands.
# Error for row BF.South.21.57: Expression evaluates to an image with no bands.
# Error for row BF.South.21.91: Expression evaluates to an image with no bands.
# Error for row BF.South.21.93: Expression evaluates to an image with no bands.
# Error for row BF.South.21.94: Expression evaluates to an image with no bands.
# Error for row BF.South.21.95: Expression evaluates to an image with no bands.
# Error for row BF.South.21.96: Expression evaluates to an image with no bands.
# Error for row CM.Est.22.138: Expression evaluates to an image with no bands.
# Error for row CM.Est.22.139: Expression evaluates to an image with no bands.
# Error for row CM.Est.22.141: Expression evaluates to an image with no bands.
# Error for row CM.Est.22.142: Expression evaluates to an image with no bands.
# Error for row CM.Est.22.56: Expression evaluates to an image with no bands.
# Error for row CM.Est.22.58: Expression evaluates to an image with no bands.
# Error for row CM.Est.22.59: Expression evaluates to an image with no bands.
# Error for row CM.Est.22.60: Expression evaluates to an image with no bands.
# Error for row CM.Est.22.61: Expression evaluates to an image with no bands.
# Error for row CM.Est.22.62: Expression evaluates to an image with no bands.
# Error for row CM.Est.22.63: Expression evaluates to an image with no bands.
# Error for row CM.Est.22.66: Expression evaluates to an image with no bands.
# Error for row CM.Est.22.67: Expression evaluates to an image with no bands.
# Error for row CM.Est.22.68: Expression evaluates to an image with no bands.
# Error for row CM.Est.22.69: Expression evaluates to an image with no bands.
# Error for row CM.Est.22.70: Expression evaluates to an image with no bands.
# Error for row CM.Est.22.71: Expression evaluates to an image with no bands.
# Error for row CM.Est.22.72: Expression evaluates to an image with no bands.
# Error for row CI.Center East.35.153: Expression evaluates to an image with no bands.
# Error for row BJ.Borgou.31.30201042: Expression evaluates to an image with no bands.
# Error for row BJ.Borgou.31.30251016: Expression evaluates to an image with no bands.
# Error for row BJ.Borgou.31.30304039: Expression evaluates to an image with no bands.
# Error for row BJ.Borgou.31.30402025: Expression evaluates to an image with no bands.
# 429: Too Many Requests
# Error for row BJ.Borgou.31.30801037: Expression evaluates to an image with no bands.
# Error for row BJ.Borgou.31.30903011: Expression evaluates to an image with no bands.
# Error for row BJ.Borgou.31.30951049: Expression evaluates to an image with no bands.
# Error for row BJ.Borgou.31.31051016: Expression evaluates to an image with no bands.
# Error for row BJ.Borgou.31.31052031: Expression evaluates to an image with no bands.
# Error for row BJ.Borgou.31.31053005: Expression evaluates to an image with no bands.
# Error for row BJ.Borgou.31.31054074: Expression evaluates to an image with no bands.
# Error for row BJ.Borgou.31.31055046: Expression evaluates to an image with no bands.
# Error for row BJ.Borgou.31.31104011: Expression evaluates to an image with no bands.
# Error for row BJ.Borgou.31.31301001: Expression evaluates to an image with no bands.
# Error for row BJ.Borgou.31.31351039: Expression evaluates to an image with no bands.
# Error for row BJ.Borgou.31.31401040: Expression evaluates to an image with no bands.
# Error for row BJ.Borgou.31.31405054: Expression evaluates to an image with no bands.
# Error for row BJ.Borgou.31.31451031: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.601: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.602: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.603: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.604: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.605: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.606: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.607: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.608: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.609: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.610: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.611: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.612: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.613: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.614: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.615: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.616: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.617: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.618: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.619: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.620: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.621: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.622: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.623: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.624: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.625: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.626: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.627: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.628: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.629: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.630: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.631: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.632: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.633: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.634: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.635: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.636: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.637: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.638: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.639: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.640: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.641: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.642: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.643: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.644: Expression evaluates to an image with no bands.
# Error for row CF.Bangui.31.645: Expression evaluates to an image with no bands.
# Error for row CF.Rs I.31.101: Expression evaluates to an image with no bands.
# Error for row CF.Rs I.31.102: Expression evaluates to an image with no bands.
# Error for row CF.Rs I.31.103: Expression evaluates to an image with no bands.
# Error for row CM.Ouest.22.131: Expression evaluates to an image with no bands.
# Error for row CM.Ouest.22.132: Expression evaluates to an image with no bands.
# Error for row CM.Ouest.22.133: Expression evaluates to an image with no bands.
# Error for row CM.Ouest.22.135: Expression evaluates to an image with no bands.
# Error for row CM.Ouest.22.136: Expression evaluates to an image with no bands.
# Error for row CF.Rs I.31.112: Expression evaluates to an image with no bands.
# Error for row CF.Rs I.31.113: Expression evaluates to an image with no bands.
# Error for row CF.Rs I.31.114: Expression evaluates to an image with no bands.
# Error for row CF.Rs I.31.115: Expression evaluates to an image with no bands.
# Error for row CM.Ouest.22.37: Expression evaluates to an image with no bands.
# Error for row CM.Ouest.22.38: Expression evaluates to an image with no bands.
# Error for row CM.Ouest.22.39: Expression evaluates to an image with no bands.
# Error for row CM.Ouest.22.40: Expression evaluates to an image with no bands.
# Error for row CF.Rs I.31.118: Expression evaluates to an image with no bands.
# Error for row CM.Ouest.22.41: Expression evaluates to an image with no bands.
# Error for row CF.Rs I.31.119: Expression evaluates to an image with no bands.
# Error for row CF.Rs I.31.120: Expression evaluates to an image with no bands.
# Error for row CM.Ouest.22.42: Expression evaluates to an image with no bands.
# Error for row CF.Rs I.31.121: Expression evaluates to an image with no bands.
# Error for row CF.Rs I.31.134: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.201: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.202: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.203: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.204: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.205: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.206: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.207: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.208: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.211: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.212: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.213: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.214: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.215: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.216: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.217: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.218: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.219: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.220: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.221: Expression evaluates to an image with no bands.
# Error for row CM.Yaoundé.douala.22.73: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.222: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.223: Expression evaluates to an image with no bands.
# Error for row CM.Yaoundé.douala.22.74: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.224: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.225: Expression evaluates to an image with no bands.
# Error for row CM.Yaoundé.douala.22.75: Expression evaluates to an image with no bands.
# Error for row CM.Yaoundé.douala.22.76: Expression evaluates to an image with no bands.
# Error for row CM.Yaoundé.douala.22.77: Expression evaluates to an image with no bands.
# Error for row CM.Yaoundé.douala.22.78: Expression evaluates to an image with no bands.
# Error for row CM.Yaoundé.douala.22.79: Expression evaluates to an image with no bands.
# Error for row CM.Yaoundé.douala.22.80: Expression evaluates to an image with no bands.
# Error for row CM.Yaoundé.douala.22.81: Expression evaluates to an image with no bands.
# Error for row CM.Yaoundé.douala.22.82: Expression evaluates to an image with no bands.
# Error for row CM.Yaoundé.douala.22.83: Expression evaluates to an image with no bands.
# Error for row CM.Yaoundé.douala.22.84: Expression evaluates to an image with no bands.
# Error for row CM.Yaoundé.douala.22.85: Expression evaluates to an image with no bands.
# Error for row CM.Yaoundé.douala.22.86: Expression evaluates to an image with no bands.
# Error for row CM.Yaoundé.douala.22.87: Expression evaluates to an image with no bands.
# Error for row CM.Yaoundé.douala.22.88: Expression evaluates to an image with no bands.
# Error for row CM.Yaoundé.douala.22.89: Expression evaluates to an image with no bands.
# Error for row CM.Yaoundé.douala.22.90: Expression evaluates to an image with no bands.
# Error for row CM.Yaoundé.douala.22.91: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.230: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.231: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.232: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.233: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.235: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.236: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.237: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.238: Expression evaluates to an image with no bands.
# Error for row CF.Rs Ii.31.239: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iii.31.303: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iii.31.304: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iii.31.305: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iii.31.306: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iii.31.320: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iii.31.321: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iii.31.322: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iii.31.323: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iii.31.324: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iii.31.325: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iii.31.326: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iii.31.327: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iii.31.328: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iii.31.329: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iii.31.330: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iii.31.331: Expression evaluates to an image with no bands.
# Error for row BJ.Atacora.31.10101049: Expression evaluates to an image with no bands.
# Error for row BJ.Atacora.31.10151020: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iv.31.404: Expression evaluates to an image with no bands.
# Error for row BJ.Atacora.31.10401006: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iv.31.405: Expression evaluates to an image with no bands.
# Error for row BJ.Atacora.31.10451022: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iv.31.406: Expression evaluates to an image with no bands.
# Error for row BJ.Atacora.31.10551012: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iv.31.407: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iv.31.409: Expression evaluates to an image with no bands.
# Error for row BJ.Atacora.31.10552026: Expression evaluates to an image with no bands.
# Error for row BJ.Atacora.31.10553038: Expression evaluates to an image with no bands.
# Error for row BJ.Atacora.31.10601008: Expression evaluates to an image with no bands.
# Error for row BJ.Atacora.31.10606047: Expression evaluates to an image with no bands.
# Error for row BJ.Atacora.31.10609024: Expression evaluates to an image with no bands.
# Error for row BJ.Atacora.31.10751017: Expression evaluates to an image with no bands.
# Error for row BJ.Atacora.31.10851026: Expression evaluates to an image with no bands.
# Error for row BJ.Atacora.31.11051004: Expression evaluates to an image with no bands.
# Error for row BJ.Atacora.31.11053026: Expression evaluates to an image with no bands.
# Error for row BJ.Atacora.31.11204006: Expression evaluates to an image with no bands.
# Error for row BJ.Atacora.31.11301001: Expression evaluates to an image with no bands.
# Error for row BJ.Atacora.31.11351011: Expression evaluates to an image with no bands.
# Error for row BJ.Atacora.31.11401038: Expression evaluates to an image with no bands.
# Error for row BJ.Atacora.31.11451020: Expression evaluates to an image with no bands.
# Error for row BJ.Atacora.31.11501013: Expression evaluates to an image with no bands.
# 429: Too Many Requests
# 429: Too Many Requests
# Error for row CF.Rs Iv.31.422: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iv.31.423: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iv.31.425: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iv.31.426: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iv.31.427: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iv.31.428: Expression evaluates to an image with no bands.
# Error for row CF.Rs Iv.31.429: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.60151037: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.60153009: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.60203036: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.60208022: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.60303033: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.60308003: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.60408058: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.60452017: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.60452028: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.60552013: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.60555025: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.60603024: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.60606055: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.60651034: Expression evaluates to an image with no bands.
# 429: Too Many Requests
# Error for row BJ.Zou.31.60704073: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.60751001: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.60803004: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.60805034: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.60907033: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.61001021: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.61109049: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.61151052: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.61201004: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.61252023: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.61305002: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.61401002: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.61402037: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.61451017: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.61506013: Expression evaluates to an image with no bands.
# Error for row BJ.Zou.31.61508057: Expression evaluates to an image with no bands.
# 429: Too Many Requests
# 429: Too Many Requests
# Error for row BF.Ouest.21.111: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.112: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.113: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.114: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.127: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.128: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.130: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.143: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.144: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.145: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.146: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.147: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.148: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.149: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.150: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.151: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.152: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.153: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.154: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.155: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.156: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.157: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.161: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.162: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.163: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.164: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.165: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.181: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.182: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.183: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.184: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.58: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.59: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.60: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.63: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.64: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40101023: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40102035: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40103049: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.65: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40151011: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.66: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40201018: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.67: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40202025: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40301017: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40302030: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.68: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40351011: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.69: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40401025: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.70: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.71: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40451009: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.72: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40502025: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40506055: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40551001: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.73: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.74: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40601036: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.75: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40606065: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40651006: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40651023: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.76: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40751002: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.77: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40802048: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.78: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.79: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40852012: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40901016: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40905054: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.40951004: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.80: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.41007057: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.81: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.41051006: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.82: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.41103041: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.41151012: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.41202023: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.83: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.84: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.85: Expression evaluates to an image with no bands.
# Error for row BJ.Mono.31.41204034: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.86: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.87: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.88: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.89: Expression evaluates to an image with no bands.
# Error for row BF.Ouest.21.92: Expression evaluates to an image with no bands.
# Error for row CM.Littoral.22.151: Expression evaluates to an image with no bands.
# Error for row CM.Littoral.22.153: Expression evaluates to an image with no bands.
# Error for row BF.East.21.116: Expression evaluates to an image with no bands.
# Error for row BF.East.21.118: Expression evaluates to an image with no bands.
# Error for row BF.East.21.119: Expression evaluates to an image with no bands.
# Error for row BF.East.21.120: Expression evaluates to an image with no bands.
# Error for row BF.East.21.121: Expression evaluates to an image with no bands.
# Error for row BF.East.21.132: Expression evaluates to an image with no bands.
# Error for row BF.East.21.133: Expression evaluates to an image with no bands.
# Error for row BF.East.21.138: Expression evaluates to an image with no bands.
# Error for row BF.East.21.141: Expression evaluates to an image with no bands.
# Error for row BF.East.21.142: Expression evaluates to an image with no bands.
# Error for row BF.East.21.158: Expression evaluates to an image with no bands.
# Error for row BF.East.21.166: Expression evaluates to an image with no bands.
# Error for row BF.East.21.167: Expression evaluates to an image with no bands.
# Error for row BF.East.21.170: Expression evaluates to an image with no bands.
# Error for row BF.East.21.210: Expression evaluates to an image with no bands.
# Error for row BF.East.21.212: Expression evaluates to an image with no bands.
# Error for row BF.East.21.220: Expression evaluates to an image with no bands.
# Error for row BF.East.21.52: Expression evaluates to an image with no bands.
# Error for row BF.East.21.53: Expression evaluates to an image with no bands.
# Error for row BF.East.21.61: Expression evaluates to an image with no bands.
# Error for row BF.East.21.62: Expression evaluates to an image with no bands.
# Error for row BF.East.21.90: Expression evaluates to an image with no bands.
# 429: Too Many Requests
# Error for row CM.Adamaoua.22.1: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.10: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.11: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.116: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.117: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.118: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.119: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.12: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.120: Expression evaluates to an image with no bands.
# Error for row CM.Adamaoua.22.121: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20101021: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20102039: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20102051: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20105060: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20151003: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20204037: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20352018: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20353010: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20354049: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20356032: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20356044: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20357002: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20358021: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20359038: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20360052: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20361004: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20362019: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20363004: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20364036: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20366016: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20366036: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20367051: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20368079: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20368099: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20369106: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20369117: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20370025: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20370046: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20371017: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20372088: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20372105: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20373071: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20374051: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20505047: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20552009: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20606044: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20702013: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.1: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20709050: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.10: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20801013: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.11: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20851005: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.12: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20907037: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.13: Expression evaluates to an image with no bands.
# Error for row BJ.Atlantique.31.20909048: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.14: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.15: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.16: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.17: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.18: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.19: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.2: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.20: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.21: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.22: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.23: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.24: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.25: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.26: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.261: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.27: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.28: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.29: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.291: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.3: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.30: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.31: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.32: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.321: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.33: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.34: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.35: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.36: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.37: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.371: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.38: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.381: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.39: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.391: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.4: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.40: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.401: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.41: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.411: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.42: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.43: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.44: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.45: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.46: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.47: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.48: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.49: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.5: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.50: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.51: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.6: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.7: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.8: Expression evaluates to an image with no bands.
# Error for row BF.Center.21.9: Expression evaluates to an image with no bands.
# Error for row GH.Eastern.41.148: Expression evaluates to an image with no bands.
# Error for row GH.Eastern.41.153: Expression evaluates to an image with no bands.
# Error for row GH.Eastern.41.154: Expression evaluates to an image with no bands.
# 429: Too Many Requests
# Error for row GH.Eastern.41.156: Expression evaluates to an image with no bands.
# Error for row GH.Eastern.41.160: Expression evaluates to an image with no bands.
# Error for row GH.Volta.31.280: Expression evaluates to an image with no bands.
# Error for row GH.Volta.31.31: Expression evaluates to an image with no bands.
# Error for row GH.Volta.31.319: Expression evaluates to an image with no bands.
# Error for row GH.Volta.31.32: Expression evaluates to an image with no bands.
# Error for row GH.Volta.31.321: Expression evaluates to an image with no bands.
# Error for row GH.Volta.31.322: Expression evaluates to an image with no bands.
# Error for row GH.Volta.31.323: Expression evaluates to an image with no bands.
# Error for row GH.Eastern.41.162: Expression evaluates to an image with no bands.
# Error for row GH.Eastern.41.163: Expression evaluates to an image with no bands.
# Error for row GH.Volta.31.324: Expression evaluates to an image with no bands.
# Error for row GH.Volta.31.325: Expression evaluates to an image with no bands.
# Error for row GH.Eastern.41.165: Expression evaluates to an image with no bands.
# Error for row GH.Volta.31.326: Expression evaluates to an image with no bands.
# Error for row GH.Volta.31.33: Expression evaluates to an image with no bands.
# Error for row GH.Eastern.41.166: Expression evaluates to an image with no bands.
# ...
# Error for row SN.Ouest.32.191: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.192: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.194: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.195: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.199: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.2: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.20: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.200: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.203: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.204: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.205: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.206: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.207: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.209: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.21: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.210: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.22: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.23: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.24: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.25: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.26: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.27: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.28: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.29: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.3: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.30: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.4: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.5: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.6: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.7: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.8: Expression evaluates to an image with no bands.
# Error for row SN.Ouest.32.9: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.201: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.100: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.202: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.101: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.203: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.102: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.103: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.104: Expression evaluates to an image with no bands.
# 429: Too Many Requests
# Error for row SN.Center.21.105: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.106: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.107: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.205: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.108: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.207: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.109: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.208: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.209: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.110: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.210: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.111: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.112: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.113: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.212: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.114: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.213: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.115: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.116: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.117: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.118: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.215: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.119: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.216: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.181: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.182: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.217: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.218: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.186: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.219: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.220: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.221: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.187: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.188: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.189: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.223: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.224: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.190: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.225: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.226: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.191: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.227: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.192: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.194: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.229: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.230: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.231: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.202: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.233: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.234: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.235: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.236: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.237: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.238: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.239: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.240: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.241: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.242: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.243: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.244: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.245: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.246: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.247: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.248: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.249: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.250: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.251: Expression evaluates to an image with no bands.
# Error for row TG.Plateaux.31.252: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.210: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.211: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.212: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.213: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.214: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.215: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.216: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.219: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.220: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.221: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.223: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.224: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.225: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.226: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.227: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.229: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.230: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.232: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.233: Expression evaluates to an image with no bands.
# Error for row SN.Center.21.99: Expression evaluates to an image with no bands.
# Error for row SN.Center.32.151: Expression evaluates to an image with no bands.
# Error for row SN.Center.32.152: Expression evaluates to an image with no bands.
# 429: Too Many Requests
# Error for row SN.Center.32.153: Expression evaluates to an image with no bands.
# Error for row SN.Center.32.154: Expression evaluates to an image with no bands.
# Error for row SN.Center.32.155: Expression evaluates to an image with no bands.
# Error for row SN.Center.32.156: Expression evaluates to an image with no bands.
# Error for row SN.Center.32.157: Expression evaluates to an image with no bands.
# Error for row SN.Center.32.159: Expression evaluates to an image with no bands.
# Error for row SN.Center.32.161: Expression evaluates to an image with no bands.
# Error for row SN.Center.32.163: Expression evaluates to an image with no bands.
# Error for row SN.Center.32.164: Expression evaluates to an image with no bands.
# Error for row SN.Center.32.166: Expression evaluates to an image with no bands.
# Error for row SN.Center.32.167: Expression evaluates to an image with no bands.
# Error for row SN.Center.32.169: Expression evaluates to an image with no bands.
# Error for row SN.Center.32.170: Expression evaluates to an image with no bands.
# Error for row SN.Center.32.171: Expression evaluates to an image with no bands.
# Error for row SN.Center.32.172: Expression evaluates to an image with no bands.
# Error for row SN.Center.32.173: Expression evaluates to an image with no bands.
# Error for row SN.Center.32.174: Expression evaluates to an image with no bands.
# 429: Too Many Requests
# Error for row TG.Centrale.31.305: Expression evaluates to an image with no bands.
# Error for row TG.Centrale.31.320: Expression evaluates to an image with no bands.
# Error for row TG.Centrale.31.331: Expression evaluates to an image with no bands.
# Error for row SN.South.21.154: Expression evaluates to an image with no bands.
# Error for row SN.South.21.155: Expression evaluates to an image with no bands.
# Error for row SN.South.21.156: Expression evaluates to an image with no bands.
# Error for row SN.South.21.157: Expression evaluates to an image with no bands.
# Error for row SN.South.21.159: Expression evaluates to an image with no bands.
# Error for row SN.South.21.160: Expression evaluates to an image with no bands.
# Error for row SN.South.21.161: Expression evaluates to an image with no bands.
# Error for row SN.South.21.162: Expression evaluates to an image with no bands.
# Error for row SN.South.21.163: Expression evaluates to an image with no bands.
# Error for row SN.South.21.164: Expression evaluates to an image with no bands.
# Error for row SN.South.21.165: Expression evaluates to an image with no bands.
# Error for row SN.South.21.166: Expression evaluates to an image with no bands.
# Error for row SN.South.21.167: Expression evaluates to an image with no bands.
# Error for row SN.South.21.168: Expression evaluates to an image with no bands.
# Error for row SN.South.21.171: Expression evaluates to an image with no bands.
# Error for row SN.South.21.172: Expression evaluates to an image with no bands.
# Error for row SN.South.21.173: Expression evaluates to an image with no bands.
# Error for row SN.South.21.174: Expression evaluates to an image with no bands.
# Error for row SN.South.21.175: Expression evaluates to an image with no bands.
# Error for row SN.South.21.176: Expression evaluates to an image with no bands.
# Error for row SN.South.21.177: Expression evaluates to an image with no bands.
# Error for row SN.South.21.178: Expression evaluates to an image with no bands.
# Error for row SN.South.21.87: Expression evaluates to an image with no bands.
# Error for row SN.South.21.88: Expression evaluates to an image with no bands.
# Error for row SN.South.21.89: Expression evaluates to an image with no bands.
# Error for row SN.South.21.90: Expression evaluates to an image with no bands.
# Error for row SN.South.21.91: Expression evaluates to an image with no bands.
# Error for row SN.South.21.92: Expression evaluates to an image with no bands.
# Error for row SN.South.21.93: Expression evaluates to an image with no bands.
# Error for row SN.South.21.94: Expression evaluates to an image with no bands.
# Error for row SN.South.21.95: Expression evaluates to an image with no bands.
# Error for row SN.South.21.96: Expression evaluates to an image with no bands.
# Error for row SN.South.21.97: Expression evaluates to an image with no bands.
# Error for row SN.South.21.98: Expression evaluates to an image with no bands.
# Error for row SN.South.32.292: Expression evaluates to an image with no bands.
# Error for row SN.South.32.293: Expression evaluates to an image with no bands.
# Error for row SN.South.32.294: Expression evaluates to an image with no bands.
# Error for row SN.South.32.296: Expression evaluates to an image with no bands.
# Error for row SN.South.32.297: Expression evaluates to an image with no bands.
# Error for row SN.South.32.298: Expression evaluates to an image with no bands.
# Error for row SN.South.32.300: Expression evaluates to an image with no bands.
# Error for row SN.South.32.310: Expression evaluates to an image with no bands.
# Error for row SN.South.32.315: Expression evaluates to an image with no bands.
# Error for row SN.South.32.316: Expression evaluates to an image with no bands.
# Error for row SN.South.32.317: Expression evaluates to an image with no bands.
# Error for row SN.South.32.318: Expression evaluates to an image with no bands.
# Error for row SN.South.32.319: Expression evaluates to an image with no bands.
# Error for row SN.South.32.320: Expression evaluates to an image with no bands.
# Error for row TZ.Kagera.41.288: Expression evaluates to an image with no bands.
